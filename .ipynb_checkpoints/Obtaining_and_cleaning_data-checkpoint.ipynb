# %% [markdown]
# # OSEMN DS Model

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>
#
# ## Business Problem
#
#
# <img src="images/top_rated_movies.jpg" style="width:400px;height:170px"/>
#
#
# USAA wants to determine what factors should affect their home insurance premiums. In this project, regression models will analyze which home features (square footage, condition, etc.) best predict a house prices. The model will be trained and tested to see how well the model predicts house prices. Then, recommendations will be made to determine which features should raise, lower, or not affect premiums.

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>
#
# ## Obtain Data
# - Understand stakeholder requirements
# - Gather information on the problem
# - Source data necessary for the problem
#
# **Business Problem:**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from datetime import datetime
# %matplotlib inline

# %%
df = pd.read_csv('data/kc_house_data.csv')
pd.set_option('display.max_columns', 50) #view all columns
print(df.shape)
df.head()
# Out:
# (21597, 21)
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0         NaN   0.0          3      7        1180
# 1      7242     2.0         0.0   0.0          3      7        2170
# 2     10000     1.0         0.0   0.0          3      6         770
# 3      5000     1.0         0.0   0.0          5      7        1050
# 4      8080     1.0         0.0   0.0          3      8        1680
#
#   sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0           0.0      1955           0.0    98178  47.5112 -122.257
# 1         400.0      1951        1991.0    98125  47.7210 -122.319
# 2           0.0      1933           NaN    98028  47.7379 -122.233
# 3         910.0      1965           0.0    98136  47.5208 -122.393
# 4           0.0      1987           0.0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           21534 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
#  17  lat            21597 non-null  float64
#  18  long           21597 non-null  float64
#  19  sqft_living15  21597 non-null  int64
#  20  sqft_lot15     21597 non-null  int64
# dtypes: float64(8), int64(11), object(2)
# memory usage: 3.5+ MB

# %% [markdown]
# **Column Names and descriptions for Kings County Data Set**
# * **id** - unique identifier for a house
# * **date** - date house was sold
# * **price** - price: prediction target
# * **bedrooms** - number of Bedrooms/House
# * **bathrooms** - number of bathrooms/bedrooms
# * **sqft_living** - sqft footage of the home
# * **sqft_lot** - sqft footage of the lot
# * **floors** - total floors (levels) in house
# * **waterfront** - house has a view to a waterfront
# * **view** - has been view
# * **condition** - house condition (quality)
# * **grade** - overall grade given to the housing unit, based on King County grading system
# * **sqft_above** - sqft house apart from basement
# * **sqft_basement** - sqft of basement
# * **yr_built** - year built
# * **yr_renovated** - year house was renovated
# * **zipcode** - zip
# * **lat** - Latitude coordinate
# * **long** - Longitude coordinate
# * **sqft_living15** - sqft of interior housing living space of 15 nearest neighbors
# * **sqft_lot15** - sqft of the land lots of 15 nearest neighbors

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>
#
# ## Scrub Data
# - Identify and deal with null/missing values
# - Deal with outliers
# - Normalize/Standardize data
# - Feature engineering/selection
# - One-hot encode categorical variables (often done after EDA)

# %% [markdown]
# #### Drop duplicates
# Check rows and identifiers ('id')

# %%
print(df.duplicated().sum())
print(df['id'].duplicated(keep = False).sum())
# for col in df.columns:
#    print(f'{col}: ', df[col].duplicated().sum())
# Out:
# 0
# 353

# %%
# df.set_index('id', inplace = True)
df_id_dups = df[df.duplicated('id', keep=False)]
df_id_dups
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 93     6021501535   7/25/2014   430000.0         3       1.50         1580
# 94     6021501535  12/23/2014   700000.0         3       1.50         1580
# 313    4139480200   6/18/2014  1380000.0         4       3.25         4290
# 314    4139480200   12/9/2014  1400000.0         4       3.25         4290
# 324    7520000520    9/5/2014   232000.0         2       1.00         1240
# ...           ...         ...        ...       ...        ...          ...
# 20654  8564860270   3/30/2015   502000.0         4       2.50         2680
# 20763  6300000226   6/26/2014   240000.0         4       1.00         1200
# 20764  6300000226    5/4/2015   380000.0         4       1.00         1200
# 21564  7853420110   10/3/2014   594866.0         3       3.00         2780
# 21565  7853420110    5/4/2015   625000.0         3       3.00         2780
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 93         5000     1.0         0.0   0.0          3      8        1290
# 94         5000     1.0         0.0   0.0          3      8        1290
# 313       12103     1.0         0.0   3.0          3     11        2690
# 314       12103     1.0         0.0   3.0          3     11        2690
# 324       12092     1.0         NaN   0.0          3      6         960
# ...         ...     ...         ...   ...        ...    ...         ...
# 20654      5539     2.0         NaN   0.0          3      8        2680
# 20763      2171     1.5         0.0   0.0          3      7        1200
# 20764      2171     1.5         0.0   0.0          3      7        1200
# 21564      6000     2.0         0.0   0.0          3      9        2780
# 21565      6000     2.0         0.0   0.0          3      9        2780
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 93            290.0      1939           0.0    98117  47.6870 -122.386
# 94            290.0      1939           0.0    98117  47.6870 -122.386
# 313          1600.0      1997           0.0    98006  47.5503 -122.102
# 314          1600.0      1997           0.0    98006  47.5503 -122.102
# 324           280.0      1922        1984.0    98146  47.4957 -122.352
# ...             ...       ...           ...      ...      ...      ...
# 20654           0.0      2013           0.0    98045  47.4759 -121.734
# 20763           0.0      1933           0.0    98133  47.7076 -122.342
# 20764           0.0      1933           0.0    98133  47.7076 -122.342
# 21564           0.0      2013           0.0    98065  47.5184 -121.886
# 21565           0.0      2013           NaN    98065  47.5184 -121.886
#
#        sqft_living15  sqft_lot15
# 93              1570        4500
# 94              1570        4500
# 313             3860       11244
# 314             3860       11244
# 324             1820        7460
# ...              ...         ...
# 20654           2680        5992
# 20763           1130        1598
# 20764           1130        1598
# 21564           2850        6000
# 21565           2850        6000
#
# [353 rows x 21 columns]

# %% [markdown]
# The only difference between the duplicate id entries is the price, so it's likely and update was just being made for price sold or the house was quickly flipped within a year. Regardless, we'll keep the last entry.

# %%
df.drop_duplicates('id', keep='last', inplace= True)
df['id'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Dealing with data types
# Investigate and deal with String/Object columns, 'date' and 'sqft_basement'

# %%
df['sqft_basement'].value_counts(normalize=True)
# Out:
# 0.0       0.593651
# ?         0.021102
# 600.0     0.010084
# 500.0     0.009617
# 700.0     0.009617
#             ...
# 2180.0    0.000047
# 1284.0    0.000047
# 2500.0    0.000047
# 417.0     0.000047
# 518.0     0.000047
# Name: sqft_basement, Length: 304, dtype: float64

# %% [markdown]
# Turn '?' into appropriate missing value (np.NaN), so we can convert column into float 64. Convert

# %%
df['sqft_basement'].replace(to_replace='?', value=np.NaN, inplace = True)
df['sqft_basement'].value_counts(normalize=True, dropna=False)    # see how many rows are missing values
# Out:
# 0.0       0.593651
# NaN       0.021102
# 600.0     0.010084
# 700.0     0.009617
# 500.0     0.009617
#             ...
# 10.0      0.000047
# 1548.0    0.000047
# 2600.0    0.000047
# 3000.0    0.000047
# 2310.0    0.000047
# Name: sqft_basement, Length: 304, dtype: float64

# %%
df['date'] = pd.to_datetime(df['date'])
df = df.astype({'sqft_basement':'float64'})
display(df.head())
df.info()    # check data types again
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0         NaN   0.0          3      7        1180
# 1      7242     2.0         0.0   0.0          3      7        2170
# 2     10000     1.0         0.0   0.0          3      6         770
# 3      5000     1.0         0.0   0.0          5      7        1050
# 4      8080     1.0         0.0   0.0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0            0.0      1955           0.0    98178  47.5112 -122.257
# 1          400.0      1951        1991.0    98125  47.7210 -122.319
# 2            0.0      1933           NaN    98028  47.7379 -122.233
# 3          910.0      1965           0.0    98136  47.5208 -122.393
# 4            0.0      1987           0.0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21420 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21420 non-null  int64
#  1   date           21420 non-null  datetime64[ns]
#  2   price          21420 non-null  float64
#  3   bedrooms       21420 non-null  int64
#  4   bathrooms      21420 non-null  float64
#  5   sqft_living    21420 non-null  int64
#  6   sqft_lot       21420 non-null  int64
#  7   floors         21420 non-null  float64
#  8   waterfront     19067 non-null  float64
#  9   view           21357 non-null  float64
#  10  condition      21420 non-null  int64
#  11  grade          21420 non-null  int64
#  12  sqft_above     21420 non-null  int64
#  13  sqft_basement  20968 non-null  float64
#  14  yr_built       21420 non-null  int64
#  15  yr_renovated   17607 non-null  float64
#  16  zipcode        21420 non-null  int64
#  17  lat            21420 non-null  float64
#  18  long           21420 non-null  float64
#  19  sqft_living15  21420 non-null  int64
#  20  sqft_lot15     21420 non-null  int64
# dtypes: datetime64[ns](1), float64(9), int64(11)
# memory usage: 3.6 MB

# %% [markdown]
# #### Filling Missing Values

# %%
df.isna().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2353
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement     452
# yr_built            0
# yr_renovated     3813
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
for col in df.columns:    # loop through columns
    print(f'"{col}" Value Counts:\n',
          df[col].value_counts(normalize=True).head(),
          '\n NumUnique:', df[col].nunique(), '\n')
# set ascending parameter to False for possible extraneuous values
# Out:
# "id" Value Counts:
#  2911700010    0.000047
# 5450300010    0.000047
# 5104511600    0.000047
# 1160000115    0.000047
# 686530110     0.000047
# Name: id, dtype: float64
#  NumUnique: 21420
#
# "date" Value Counts:
#  2014-06-23    0.006629
# 2014-06-25    0.006069
# 2014-06-26    0.005929
# 2015-04-27    0.005882
# 2015-03-25    0.005742
# Name: date, dtype: float64
#  NumUnique: 372
#
# "price" Value Counts:
#  450000.0    0.008030
# 350000.0    0.007796
# 550000.0    0.007330
# 500000.0    0.007049
# 425000.0    0.006956
# Name: price, dtype: float64
#  NumUnique: 3595
#
# "bedrooms" Value Counts:
#  3    0.454295
# 4    0.319748
# 2    0.127731
# 5    0.074043
# 6    0.012372
# Name: bedrooms, dtype: float64
#  NumUnique: 12
#
# "bathrooms" Value Counts:
#  2.50    0.249860
# 1.00    0.177124
# 1.75    0.140990
# 2.25    0.094818
# 2.00    0.089309
# Name: bathrooms, dtype: float64
#  NumUnique: 29
#
# "sqft_living" Value Counts:
#  1300    0.006349
# 1440    0.006209
# 1400    0.006162
# 1660    0.005976
# 1800    0.005976
# Name: sqft_living, dtype: float64
#  NumUnique: 1034
#
# "sqft_lot" Value Counts:
#  5000    0.016573
# 6000    0.013352
# 4000    0.011625
# 7200    0.010177
# 7500    0.005509
# Name: sqft_lot, dtype: float64
#  NumUnique: 9776
#
# "floors" Value Counts:
#  1.0    0.492624
# 2.0    0.382960
# 1.5    0.088142
# 3.0    0.028431
# 2.5    0.007516
# Name: floors, dtype: float64
#  NumUnique: 6
#
# "waterfront" Value Counts:
#  0.0    0.992343
# 1.0    0.007657
# Name: waterfront, dtype: float64
#  NumUnique: 2
#
# "view" Value Counts:
#  0.0    0.901484
# 2.0    0.044763
# 3.0    0.023646
# 1.0    0.015405
# 4.0    0.014702
# Name: view, dtype: float64
#  NumUnique: 5
#
# "condition" Value Counts:
#  3    0.648926
# 4    0.263445
# 5    0.078758
# 2    0.007563
# 1    0.001307
# Name: condition, dtype: float64
#  NumUnique: 5
#
# "grade" Value Counts:
#  7     0.414986
# 8     0.282026
# 9     0.121662
# 6     0.093137
# 10    0.052754
# Name: grade, dtype: float64
#  NumUnique: 11
#
# "sqft_above" Value Counts:
#  1300    0.009804
# 1010    0.009524
# 1200    0.009477
# 1220    0.008683
# 1140    0.008543
# Name: sqft_above, dtype: float64
#  NumUnique: 942
#
# "sqft_basement" Value Counts:
#  0.0      0.606448
# 600.0    0.010301
# 700.0    0.009824
# 500.0    0.009824
# 800.0    0.009586
# Name: sqft_basement, dtype: float64
#  NumUnique: 303
#
# "yr_built" Value Counts:
#  2014    0.026097
# 2006    0.021148
# 2005    0.021008
# 2004    0.020028
# 2003    0.019608
# Name: yr_built, dtype: float64
#  NumUnique: 116
#
# "yr_renovated" Value Counts:
#  0.0       0.957971
# 2014.0    0.004146
# 2003.0    0.001761
# 2013.0    0.001761
# 2007.0    0.001704
# Name: yr_renovated, dtype: float64
#  NumUnique: 70
#
# "zipcode" Value Counts:
#  98103    0.028011
# 98038    0.027358
# 98115    0.026891
# 98052    0.026657
# 98117    0.025584
# Name: zipcode, dtype: float64
#  NumUnique: 70
#
# "lat" Value Counts:
#  47.6624    0.000794
# 47.5322    0.000794
# 47.5491    0.000794
# 47.6846    0.000794
# 47.6711    0.000747
# Name: lat, dtype: float64
#  NumUnique: 5033
#
# "long" Value Counts:
#  -122.290    0.005275
# -122.300    0.005135
# -122.362    0.004762
# -122.291    0.004669
# -122.363    0.004622
# Name: long, dtype: float64
#  NumUnique: 751
#
# "sqft_living15" Value Counts:
#  1540    0.009010
# 1560    0.008870
# 1440    0.008870
# 1500    0.008310
# 1460    0.007843
# Name: sqft_living15, dtype: float64
#  NumUnique: 777
#
# "sqft_lot15" Value Counts:
#  5000    0.019841
# 4000    0.016527
# 6000    0.013305
# 7200    0.009757
# 4800    0.006723
# Name: sqft_lot15, dtype: float64
#  NumUnique: 8682

# %% [markdown]
# We can see most of the values (90-99%) are 0.0 for 3 of the 4 columns containing missing values. The other column, 'sqft_basement', has 60% 0.0's, but with only 2.1% of the data missing, it should be okay to fill these few missing values with the mode. It is also safer to assume NaN's mean there's no basement.

# %%
for col in ['view','sqft_basement','waterfront','yr_renovated']:    # loop through missing columns
    df[col] = df[col].fillna(value=0.0)    # fill missing values with 0.0

# %% [markdown]
# Notes on value/unique counts:
#
# Possible Binning/Binary:
# - 'bedrooms': 45%: 3, 32%: 4
# - 'bathrooms'
# - 'sqft_basement': 62%: 0
# - 'floors': 50%: 1, 38%: 2
# - 'condition': 65%: 3, 26%: 4
# - 'grade': 41%: 7, 28%: 8, 21%: >8
# - 'view': 90%: 0
# - 'yr_renovated': 96%: 0

# %% [markdown]
# #### Dealing with outliers and extraneous values

# %% [markdown]
# View descriptive stats and investigate for extraneous values and a general idea of variable distributions

# %%
df.describe(include='all', datetime_is_numeric=True)
# Out:
#                  id                           date         price  \
# count  2.142000e+04                          21420  2.142000e+04
# mean   4.580940e+09  2014-10-29 17:13:04.537815040  5.418614e+05
# min    1.000102e+06            2014-05-02 00:00:00  7.800000e+04
# 25%    2.123537e+09            2014-07-22 00:00:00  3.249500e+05
# 50%    3.904921e+09            2014-10-17 00:00:00  4.505500e+05
# 75%    7.308900e+09            2015-02-18 00:00:00  6.450000e+05
# max    9.900000e+09            2015-05-27 00:00:00  7.700000e+06
# std    2.876761e+09                            NaN  3.675569e+05
#
#            bedrooms     bathrooms   sqft_living      sqft_lot        floors  \
# count  

# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 4020   9175600025 2014-10-07   800000.0         7       6.75         7480
# 7245   6762700020 2014-10-13  7700000.0         6       8.00        12050
# 8085   1924059029 2014-06-17  4670000.0         5       6.75         9640
# 8537    424049043 2014-08-11   450000.0         9       7.50         4050
# 9245   9208900037 2014-09-19  6890000.0         6       7.75         9890
# 12764  1225069038 2014-05-05  2280000.0         7       8.00        13540
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 4020      41664     2.0         0.0   2.0          3     11        5080
# 7245      27600     2.5         0.0   3.0          4     13        8570
# 8085      13068     1.0         1.0   4.0          3     12        4820
# 8537       6504     2.0         0.0   0.0          3      7        4050
# 9245      31374     2.0         0.0   4.0          3     13        8860
# 12764    307752     3.0         0.0   4.0          3     12        9410
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 4020          2400.0      1953           0.0    98166  47.4643 -122.368
# 7245          3480.0      1910        1987.0    98102  47.6298 -122.323
# 8085          4820.0      1983        2009.0    98040  47.5570 -122.210
# 8537             0.0      1996           0.0    98144  47.5923 -122.301
# 9245          1030.0      2001           0.0    98039  47.6305 -122.240
# 12764         4130.0      1999           0.0    98053  47.6675 -121.986
#
#        sqft_living15  sqft_lot15
# 4020            2810       33190
# 7245            3940        8800
# 8085            3270       10454
# 8537            1448        3866
# 9245            4540       42730
# 12764           4850      217800

# %% [markdown]
# Because these some of these rows are likely to be dropped later as they hold many obvious outliers, we will go ahead and drop them now.

# %%
print(len(df))
len(df[~((df['bedrooms'] == 33) | (df['bathrooms'] == 8))])
# Out:
# 21420
# 21417

# %%
df=df[~((df['bedrooms'] == 33) | (df['bathrooms'] == 8))]

# %% [markdown]
# #### Bin/cut categorical variables
# View value counts of categorical variables with multiple binning

# %%
df['bedrooms'].value_counts(normalize=True)
# Out:
# 3     0.454359
# 4     0.319793
# 2     0.127749
# 5     0.074053
# 6     0.012327
# 1     0.008918
# 7     0.001728
# 8     0.000607
# 9     0.000280
# 10    0.000140
# 11    0.000047
# Name: bedrooms, dtype: float64

# %%
df['bedrooms'].value_counts(normalize=True)
# Out:
# 3     0.454359
# 4     0.319793
# 2     0.127749
# 5     0.074053
# 6     0.012327
# 1     0.008918
# 7     0.001728
# 8     0.000607
# 9     0.000280
# 10    0.000140
# 11    0.000047
# Name: bedrooms, dtype: float64

# %%
df['condition'].value_counts(normalize=True)
# Out:
# 3    0.648970
# 4    0.263436
# 5    0.078723
# 2    0.007564
# 1    0.001307
# Name: condition, dtype: float64

# %%
df['grade'].value_counts(normalize=True)
# Out:
# 7     0.414997
# 8     0.282066
# 9     0.121679
# 6     0.093150
# 10    0.052762
# 11    0.018490
# 5     0.010926
# 12    0.004062
# 4     0.001261
# 13    0.000560
# 3     0.000047
# Name: grade, dtype: float64

# %% [markdown]
# Bin/cut into categories

# %%
# Binary
df['renovated'] = df['yr_renovated'].apply(lambda x: 1 if x>0 else 0)
df['view'] = df['view'].apply(lambda x: 1 if x>0 else 0)
df['basement'] = df['sqft_basement'].apply(lambda x: 1 if x>0 else 0)
df['multilevel'] = df['floors'].apply(lambda x: 1 if x>1 else 0)
# Bins
df['bedrooms_bin'] = pd.cut(df['bedrooms'], bins=[0,2,3,4,100], labels=['1-2','3','4','5+'])
df['bathroom_bin'] = pd.cut(df['bathrooms'], bins=[0,1.75,2.5,100], labels=['0.5-1.75','2-2.5','2.75+'])
df['grade_bin'] = pd.cut(df['grade'], bins=[0,6,7,8,100], labels=['below average','average','good','great'])

# %% [markdown]
# Create more columns to see age, month, and quarter houses were sold

# %%
df['age'] = df['yr_built'].apply(lambda x: datetime.today().year - x)
df = df.set_index('date')
df['month'] = df.index.month
# df['month_name'] = df.index.month_name() # use if we want month name later
df = df.reset_index()
df['yr_quarter'] = pd.cut(df['month'], bins=[0,3,6,9,12], labels=['1','2','3','4'])
df.head()
# Out:
#         date          id     price  bedrooms  bathrooms  sqft_living  \
# 0 2014-10-13  7129300520  221900.0         3       1.00         1180
# 1 2014-12-09  6414100192  538000.0         3       2.25         2570
# 2 2015-02-25  5631500400  180000.0         2       1.00          770
# 3 2014-12-09  2487200875  604000.0         4       3.00         1960
# 4 2015-02-18  1954400510  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0         0.0     0          3      7        1180
# 1      7242     2.0         0.0     0          3      7        2170
# 2     10000     1.0         0.0     0          3      6         770
# 3      5000     1.0         0.0     0          5      7        1050
# 4      8080     1.0         0.0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0            0.0      1955           0.0    98178  47.5112 -122.257
# 1          400.0      1951        1991.0    98125  47.7210 -122.319
# 2            0.0      1933           0.0    98028  47.7379 -122.233
# 3          910.0      1965           0.0    98136  47.5208 -122.393
# 4            0.0      1987           0.0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15  renovated  basement  multilevel bedrooms_cut  \
# 0           1340        5650          0         0           0            3
# 1           1690        7639          1         1           1            3
# 2           2720        8062          0         0           0          1-2
# 3           1360        5000          0         1           0            4
# 4           1800        7503          0         0           0            3
#
#   bathroom_cut      grade_cut  age  month yr_quarter
# 0     0.5-1.75        average   66     10          4
# 1        2-2.5        average   70     12          4
# 2     0.5-1.75  below average   88      2          1
# 3        2.75+        average   56     12          4
# 4        2-2.5           good   34      2          1

# %% [markdown]
# View distributions and descriptive stats

# %%
df.hist(figsize=(14,12));

# %%
df.describe(include='all', datetime_is_numeric=True)
# Out:
#                                  date            id         price  \
# count                           21417  2.141700e+04  2.141700e+04
# unique                            NaN           NaN           NaN
# top                               NaN           NaN           NaN
# freq                              NaN           NaN           NaN
# mean    2014-10-29 17:34:40.123266560  4.581096e+09  5.414415e+05
# min               2014-05-02 00:00:00  1.000102e+06  7.800000e+04
# 25%               2014-07-22 00:00:00  2.123700e+09  3.249500e+05
# 50%               2014-10-17 00:00:00  3.904921e+09  4.505000e+05
# 75%               2015-02-18 00:00:00  7.308900e+09  6.450000e+05
# max               2015-05-27 00:00:00  9.900000e+09  7.060000e+06
# std                               NaN  2.876794e+09  3.641192e+05
#
#             bedrooms     bathrooms   sqft_living      sqft_lot        floors  \
# count   21417.000000  21417.000000  21417.000000  2.141700e+04  21417.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean        3.372274      2.117897   2082.153943  1.511422e+04      1.495891
# min         1.000000      0.500000    370.000000  5.200000e+02      1.000000
# 25%         3.000000      1.750000   1430.000000  5.040000e+03      1.000000
# 50%         3.000000      2.250000   1920.000000  7.614000e+03      1.500000
# 75%         4.000000      2.500000   2550.000000  1.068800e+04      2.000000
# max        11.000000      7.750000  10040.000000  1.651359e+06      3.500000
# std         0.902536      0.766665    912.988835  4.148541e+04      0.539967
#
#           waterfront          view     condition         grade    sqft_above  \
# count   21417.000000  21417.000000  21417.000000  21417.000000  21417.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean        0
# multilevel     0.030333  0.144966       0.300509    0.007685   0.020501
# age            0.148834 -0.409088      -0.325015   -0.069869   0.203076
# month          0.015656 -0.007817       0.004316    0.003472   0.007486
#
#                basement  multilevel       age     month
# id             0.003144    0.021011 -0.021272 -0.011124
# price          0.178561    0.263648 -0.053211 -0.008893
# bedrooms       0.159268    0.231475 -0.160568 -0.000653
# bathrooms      0.159160    0.467328 -0.508100  0.009226
# sqft_living    0.200202    0.375025 -0.319214  0.013665
# sqft_lot      -0.035647    0.012279 -0.052089 -0.002431
# floors        -0.253150    0.904985 -0.489162  0.015743
# waterfront     0.039374    0.021482  0.024853  0.008493
# view           0.188468    0.014924  0.065331 -0.006212
# condition      0.131107   -0.217649  0.365031  0.023883
# grade          0.048840    0.426959 -0.446916  0.011584
# sqft_above    -0.209847    0.545959 -0.424900  0.011498
# sqft_basement  0.822508   -0.241912  0.131738  0.007686
# yr_built      -0.165090    0.356875 -1.000000 -0.004125
# yr_renovated   0.044590    0.020577  0.202794  0.007483
# zipcode        0.160104   -0.059293  0.346133 -0.000463
# lat            0.135101    0.030333  0.148834  0.015656
# long          -0.234383    0.144966 -0.409088 -0.007817
# sqft_living15  0.043035    0.300509 -0.325015  0.004316
# sqft_lot15    -0.042302    0.007685 -0.069869  0.003472
# renovated      0.044349    0.020501  0.203076  0.007486
# basement       1.000000   -0.248757  0.165090  0.006771
# multilevel    -0.248757    1.000000 -0.356875  0.016241
# age            0.165090   -0.356875  1.000000  0.004125
# month          0.006771    0.016241  0.004125  1.000000

# %%
mask = np.zeros_like(df.corr())
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(15, 10))
    ax = sns.heatmap(df.corr(), mask=mask, cmap='coolwarm',
                     linewidths=.5, square=True, annot=True)

# %% [markdown]
# Remove columns to reduce of multicollinearity:
# - drop bathrooms, yr_built, floors, all sqft cols (except sqft_lot), yr_renovated
# - for 1 df, drop all sqft
# - for another, drop all sqft except sqft_living and sqft_lot, and drop grade

# %%
df_w_grade = df.drop(['bathrooms','sqft_living','sqft_living15','sqft_lot15', 'yr_built',
                      'yr_renovated','sqft_above','floors','sqft_basement'], axis=1)
df_w_sqft = df.drop(['bathrooms','grade','sqft_living15','sqft_lot15', 'yr_built',
                      'yr_renovated','sqft_above','floors','sqft_basement'], axis=1)
# ['sqft_living','sqft_living15','sqft_lot15',
#                      'yr_renovated','bathrooms','sqft_above']

# %% [markdown]
# Recheck heatmap for multicollinearity

# %%
mask = np.zeros_like(df_w_grade.corr())
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(10, 8))
    ax = sns.heatmap(df_w_grade.corr(), mask=mask, cmap='coolwarm',
                     linewidths=.5, square=True, annot=True)

# %%
mask = np.zeros_like(df_w_sqft.corr())
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(10, 12))
    ax = sns.heatmap(df_w_sqft.corr(), mask=mask, cmap='coolwarm',
                     linewidths=.5, square=True, annot=True)

# %% [markdown]
# #### Save cleaned data to csv

# %%
df_w_sqft.to_csv('data/clean_data_sqft.csv')
df_w_grade.to_csv('data/clean_data_grade.csv')

# %% [markdown]
# #### Notes and extra code

# %%
# df['month'] = df.date_dateformat.dt.month
